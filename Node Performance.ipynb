# %%
import matplotlib.pyplot as plt
import pandas as pd

col_list = ["TimeStamp" , "NumJobs"]
data = pd.read_csv('prova.csv' , names=col_list)

x = data["TimeStamp"]
y = data["NumJobs"]

plt.plot(x, y)
plt.xlabel('TimeStamp')
plt.ylabel('NumJobs')
plt.legend()
plt.show()
